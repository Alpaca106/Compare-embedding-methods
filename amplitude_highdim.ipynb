# %%
# ==============================================================================
# CELL 1: TRAINING VÀ LƯU KẾT QUẢ RA FILE CSV
# ==============================================================================
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import time
import json
import torch
import torch.nn as nn
import torch.optim as optim
import pennylane as qml
import numpy as np
import pandas as pd
from sklearn.datasets import load_digits, fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, f1_score
import warnings

warnings.filterwarnings('ignore')
torch.set_num_threads(8) 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Bắt đầu Training trên thiết bị: {device.type.upper()}")

# 1. HÀM TẢI DỮ LIỆU (Giữ nguyên kích thước gốc)
def load_and_preprocess_data(dataset_name):
    if dataset_name == 'sonar':
        # Bộ Sonar (60 chiều) - Phân loại Mìn và Đá
        data = fetch_openml(name='sonar', version=1, as_frame=False, parser='auto')
        X, y = data.data, LabelEncoder().fit_transform(data.target)
        
    elif dataset_name == 'fashion':
        # Bộ Fashion MNIST (784 chiều)
        data = fetch_openml(name='Fashion-MNIST', version=1, as_frame=False, parser='auto')
        # Lọc lấy nhãn '0' (Áo thun) và '1' (Quần dài)
        idx = (data.target == '0') | (data.target == '1')
        X, y = data.data[idx], data.target[idx]
        y = LabelEncoder().fit_transform(y)
        
        # MẸO QUAN TRỌNG: Cắt xuống còn 400 mẫu ngẫu nhiên để mô phỏng QML không mất cả ngày
        np.random.seed(42)
        random_indices = np.random.choice(len(X), 400, replace=False)
        X, y = X[random_indices], y[random_indices]
    
    # Chỉ chuẩn hóa, CHƯA nén PCA ở bước này
    scaler = MinMaxScaler(feature_range=(0, np.pi))
    X = scaler.fit_transform(X)
    return X, y

def create_quantum_layer(n_qubits, embedding_type, n_layers):
    dev = qml.device("default.qubit", wires=n_qubits) 
    @qml.qnode(dev, interface="torch", diff_method="backprop")
    def quantum_circuit(inputs, weights):
        if embedding_type == 'angle':
            qml.AngleEmbedding(inputs, wires=range(n_qubits), rotation='Y')
        elif embedding_type == 'amplitude':
            qml.AmplitudeEmbedding(inputs, wires=range(n_qubits), normalize=True, pad_with=0.)
        elif embedding_type == 'iqp':
            qml.IQPEmbedding(inputs, wires=range(n_qubits))
        qml.StronglyEntanglingLayers(weights, wires=range(n_qubits))
        return qml.expval(qml.PauliZ(0))
    return quantum_circuit

class HybridQMLModel(nn.Module):
    def __init__(self, n_qubits, embedding_type, n_layers):
        super().__init__()
        weight_shape = {"weights": (n_layers, n_qubits, 3)} 
        self.qlayer = qml.qnn.TorchLayer(create_quantum_layer(n_qubits, embedding_type, n_layers), weight_shape)
        self.fc = nn.Linear(1, 1)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x):
        return self.sigmoid(self.fc(self.qlayer(x).unsqueeze(1)))

# 2. CẤU HÌNH THÔNG SỐ
DATASETS = ['sonar', 'fashion']
EMBEDDING_TYPES = ['angle', 'amplitude', 'iqp'] 

NUM_RUNS = 50    
EPOCHS = 100         
INITIAL_LR = 0.1     
N_LAYERS = 5         
seeds = np.random.randint(0, 10000, size=NUM_RUNS)

# 3. VÒNG LẶP TRAINING
all_results_data = [] 

for dataset_name in DATASETS:
    X_raw, y_raw = load_and_preprocess_data(dataset_name)
    
    for emb_type in EMBEDDING_TYPES:
        print(f"\nĐang chạy: {dataset_name.upper()} | Nhúng: {emb_type.upper()}")
        all_acc, all_f1, all_times = [], [], []
        final_run_test_hist = []

        for i in range(NUM_RUNS):
            X_train, X_test, y_train, y_test = train_test_split(X_raw, y_raw, test_size=0.3, random_state=seeds[i])
            
            # --- CƠ CHẾ NÉN PCA TỰ ĐỘNG CHỐNG TRÀN RAM ---
            if emb_type in ['angle', 'iqp'] and X_train.shape[1] > 8:
                if i == 0: 
                    print(f"Dữ liệu {X_train.shape[1]} chiều quá lớn cho {emb_type.upper()}. Tự động nén PCA xuống 8 chiều!")
                pca = PCA(n_components=8, random_state=seeds[i])
                X_train = pca.fit_transform(X_train)
                X_test = pca.transform(X_test)
                
                # Chuẩn hóa lại góc xoay sau khi PCA
                scaler = MinMaxScaler(feature_range=(0, np.pi))
                X_train = scaler.fit_transform(X_train)
                X_test = scaler.transform(X_test)
            # ----------------------------------------------

            X_tr = torch.tensor(X_train, dtype=torch.float32).to(device)
            y_tr = torch.tensor(y_train, dtype=torch.float32).view(-1, 1).to(device)
            X_te = torch.tensor(X_test, dtype=torch.float32).to(device)
            
            # Tính toán số Qubit cần thiết
            n_q = X_tr.shape[1] if emb_type != 'amplitude' else int(np.ceil(np.log2(X_tr.shape[1])))
            
            model = HybridQMLModel(n_q, emb_type, n_layers=N_LAYERS).to(device)
            optimizer = optim.Adam(model.parameters(), lr=INITIAL_LR)
            criterion = nn.BCELoss()
            run_te_acc = []
            
            start_time = time.time() 
            for epoch in range(EPOCHS):
                model.train()
                optimizer.zero_grad()
                loss = criterion(model(X_tr), y_tr)
                loss.backward()
                optimizer.step()

                with torch.no_grad():
                    model.eval()
                    preds_te = (model(X_te).cpu() > 0.5).float().numpy()
                    run_te_acc.append(accuracy_score(y_test, preds_te))
                    
            run_time = time.time() - start_time
            print(f"   -> Xong Run {i+1}/{NUM_RUNS} | Qubits dùng: {n_q} | Time: {run_time:.2f}s | Acc: {run_te_acc[-1]:.4f}")

            all_acc.append(run_te_acc[-1])
            final_preds = (model(X_te).cpu() > 0.5).float().numpy()
            all_f1.append(f1_score(y_test, final_preds, average='weighted'))
            all_times.append(run_time)
            if i == NUM_RUNS - 1: final_run_test_hist = run_te_acc

        all_results_data.append({
            'Dataset': dataset_name.upper(),
            'Embedding': emb_type.upper(),
            'Accuracy': np.mean(all_acc),
            'F1_Score': np.mean(all_f1),
            'Time_Seconds': np.mean(all_times),
            'Convergence_History': json.dumps(final_run_test_hist) 
        })

df_export = pd.DataFrame(all_results_data)
csv_filename = 'qml_benchmark_results.csv'
df_export.to_csv(csv_filename, index=False)
print(f"\nĐÃ XUẤT THÀNH CÔNG DỮ LIỆU RA FILE: {csv_filename}")
# Out:
# Bắt đầu Training trên thiết bị: CUDA
#
# Đang chạy: SONAR | Nhúng: ANGLE
# Dữ liệu 60 chiều quá lớn cho ANGLE. Tự động nén PCA xuống 8 chiều!
#    -> Xong Run 1/50 | Qubits dùng: 8 | Time: 21.83s | Acc: 0.8095
#    -> Xong Run 2/50 | Qubits dùng: 8 | Time: 23.79s | Acc: 0.8413
#    -> Xong Run 3/50 | Qubits dùng: 8 | Time: 24.07s | Acc: 0.8095
#    -> Xong Run 4/50 | Qubits dùng: 8 | Time: 22.61s | Acc: 0.7460
#    -> Xong Run 5/50 | Qubits dùng: 8 | Time: 23.57s | Acc: 0.7460
#    -> Xong Run 6/50 | Qubits dùng: 8 | Time: 23.74s | Acc: 0.8254
#    -> Xong Run 7/50 | Qubits dùng: 8 | Time: 23.03s | Acc: 0.9048
#    -> Xong Run 8/50 | Qubits dùng: 8 | Time: 23.10s | Acc: 0.8254
#    -> Xong Run 9/50 | Qubits dùng: 8 | Time: 23.23s | Acc: 0.8730
#    -> Xong Run 10/50 | Qubits dùng: 8 | Time: 23.42s | Acc: 0.8254
#    -> Xong Run 11/50 | Qubits dùng: 8 | Time: 20.28s | Acc: 0.8095
#    -> Xong Run 12/50 | Qubits dùng: 8 | Time: 20.37s | Acc: 0.7778
#    -> Xong Run 13/50 | Qubits dùng: 8 | Time: 21.58s | Acc: 0.8730
#    -> Xong Run 14/50 | Qubits dùng: 8 | Time: 22.34s | Acc: 0.7460
#    -> Xong Run 15/50 | Qubits dùng: 8 | Time: 21.99s | Acc: 0.7778
#    -> Xong Run 16/50 | Qubits dùng: 8 | Time: 21.87s | Acc: 0.8413
#    -> Xong Run 17/50 | Qubits dùng: 8 | Time: 21.54s | Acc: 0.8730
#    -> Xong Run 18/50 | Qubits dùng: 8 | Time: 21.80s | Acc: 0.8889
#    -> Xong Run 19/50 | Qubits dùng: 8 | Time: 22.27s | Acc: 0.7619
#    -> Xong Run 20/50 | Qubits dùng: 8 | Time: 19.91s | Acc: 0.7619
#    -> Xong Run 21/50 | Qubits dùng: 8 | Time: 22.12s | Acc: 0.8095
#    -> Xong Run 22/50 | Qubits dùng: 8 | Time: 22.17s | Acc: 0.7778
#    -> Xong Run 23/50 | Qubits dùng: 8 | Time: 21.10s | Acc: 0.8730
#    -> Xong Run 24/50 | Qubits dùng: 8 | Time: 23.07s | Acc: 0.8730
#    -> Xong Run 25/50 | Qubits dùng: 8 | Time: 23.31s | Acc: 0.7937
#    -> Xong Run 26/50 | Qubits dùng: 8 | Time: 21.36s | Acc: 0.8889
#    -> Xong Run 27/50 | Qubits dùng: 8 | Time: 20.27s | Acc: 0.8730
#    -> Xong Run 28/50 | Qubits dùng: 8 | Time: 21.08s | Acc: 0.8095
#    -> Xong Run 29/50 | Qubits dùng: 8 | Time: 21.93s | Acc: 0.8413
#    -> Xong Run 30/50 | Qubits dùng: 8 | Time: 22.64s | Acc: 0.9206
#    -> Xong Run 31/50 | Qubits dùng: 8 | Time: 20.48s | Acc: 0.8413
#    -> Xong Run 32/50 | Qubits dùng: 8 | Time: 21.66s | Acc: 0.8254
#    -> Xong Run 33/50 | Qubits dùng: 8 | Time: 22.65s | Acc: 0.8571
#    -> Xong Run 34/50 | Qubits dùng: 8 | Time: 20.24s | Acc: 0.8095
#    -> Xong Run 35/50 | Qubits dùng: 8 | Time: 20.26s | Acc: 0.8730
#    -> Xong Run 36/50 | Qubits dùng: 8 | Time: 20.70s | Acc: 0.9206
#    -> Xong Run 37/50 | Qubits dùng: 8 | Time: 21.20s | Acc: 0.8413
#    -> Xong Run 38/50 | Qubits dùng: 8 | Time: 22.56s | Acc: 0.8889
#    -> Xong Run 39/50 | Qubits dùng: 8 | Time: 23.03s | Acc: 0.8889
#    -> Xong Run 40/50 | Qubits dùng: 8 | Time: 23.07s | Acc: 0.7460
#    -> Xong Run 41/50 | Qubits dùng: 8 | Time: 20.84s | Acc: 0.8095
#    -> Xong Run 42/50 | Qubits dùng: 8 | Time: 20.49s | Acc: 0.8730
#    -> Xong Run 43/50 | Qubits dùng: 8 | Time: 21.96s | Acc: 0.8254
#    -> Xong Run 44/50 | Qubits dùng: 8 | Time: 20.14s | Acc: 0.8571
#    -> Xong Run 45/50 | Qubits dùng: 8 | Time: 22.58s | Acc: 0.8571
#    -> Xong Run 46/50 | Qubits dùng: 8 | Time: 23.29s | Acc: 0.7937
#    -> Xong Run 47/50 | Qubits dùng: 8 | Time: 23.01s | Acc: 0.9048
#    -> Xong Run 48/50 | Qubits dùng: 8 | Time: 23.15s | Acc: 0.8254
#    -> Xong Run 49/50 | Qubits dùng: 8 | Time: 23.41s | Acc: 0.8254
#    -> Xong Run 50/50 | Qubits dùng: 8 | Time: 22.98s | Acc: 0.8730
#
# Đang chạy: SONAR | Nhúng: AMPLITUDE
#    -> Xong Run 1/50 | Qubits dùng: 6 | Time: 15.87s | Acc: 0.6984
#    -> Xong Run 2/50 | Qubits dùng: 6 | Time: 16.34s | Acc: 0.7460
#    -> Xong Run 3/50 | Qubits dùng: 6 | Time: 15.98s | Acc: 0.7619
#    -> Xong Run 4/50 | Qubits dùng: 6 | Time: 17.09s | Acc: 0.7302
#    -> Xong Run 5/50 | Qubits dùng: 6 | Time: 15.97s | Acc: 0.7619
#    -> Xong Run 6/50 | Qubits dùng: 6 | Time: 15.06s | Acc: 0.7302
#    -> Xong Run 7/50 | Qubits dùng: 6 | Time: 15.15s | Acc: 0.9048
#    -> Xong Run 8/50 | Qubits dùng: 6 | Time: 14.71s | Acc: 0.7619
#    -> Xong Run 9/50 | Qubits dùng: 6 | Time: 15.04s | Acc: 0.7302
#    -> Xong Run 10/50 | Qubits dùng: 6 | Time: 14.20s | Acc: 0.7460
#    -> Xong Run 11/50 | Qubits dùng: 6 | Time: 14.58s | Acc: 0.6984
#    -> Xong Run 12/50 | Qubits dùng: 6 | Time: 14.20s | Acc: 0.7778
#    -> Xong Run 13/50 | Qubits dùng: 6 | Time: 15.06s | Acc: 0.7778
#    -> Xong Run 14/50 | Qubits dùng: 6 | Time: 15.52s | Acc: 0.7619
#    -> Xong Run 15/50 | Qubits dùng: 6 | Time: 13.68s | Acc: 0.8254
#    -> Xong Run 16/50 | Qubits dùng: 6 | Time: 14.81s | Acc: 0.7937
#    -> Xong Run 17/50 | Qubits dùng: 6 | Time: 16.12s | Acc: 0.7143
#    -> Xong Run 18/50 | Qubits dùng: 6 | Time: 16.00s | Acc: 0.8730
#    -> Xong Run 19/50 | Qubits dùng: 6 | Time: 15.79s | Acc: 0.7460
#    -> Xong Run 20/50 | Qubits dùng: 6 | Time: 14.85s | Acc: 0.7460
#    -> Xong Run 21/50 | Qubits dùng: 6 | Time: 14.54s | Acc: 0.7302
#    -> Xong Run 22/50 | Qubits dùng: 6 | Time: 14.67s | Acc: 0.7460
#    -> Xong Run 23/50 | Qubits dùng: 6 | Time: 15.97s | Acc: 0.7778
#    -> Xong Run 24/50 | Qubits dùng: 6 | Time: 16.17s | Acc: 0.8254
#    -> Xong Run 25/50 | Qubits dùng: 6 | Time: 15.84s | Acc: 0.7619
#    -> Xong Run 26/50 | Qubits dùng: 6 | Time: 15.75s | Acc: 0.8413
#    -> Xong Run 27/50 | Qubits dùng: 6 | Time: 15.73s | Acc: 0.7619
#    -> Xong Run 28/50 | Qubits dùng: 6 | Time: 15.80s | Acc: 0.7778
#    -> Xong Run 29/50 | Qubits dùng: 6 | Time: 15.93s | Acc: 0.8095
#    -> Xong Run 30/50 | Qubits dùng: 6 | Time: 15.84s | Acc: 0.6667
#    -> Xong Run 31/50 | Qubits dùng: 6 | Time: 15.92s | Acc: 0.6984
#    -> Xong Run 32/50 | Qubits dùng: 6 | Time: 15.73s | Acc: 0.7302
#    -> Xong Run 33/50 | Qubits dùng: 6 | Time: 15.57s | Acc: 0.8254
#    -> Xong Run 34/50 | Qubits dùng: 6 | Time: 15.61s | Acc: 0.7460
#    -> Xong Run 35/50 | Qubits dùng: 6 | Time: 15.84s | Acc: 0.7143
#    -> Xong Run 36/50 | Qubits dùng: 6 | Time: 15.67s | Acc: 0.8571
#    -> Xong Run 37/50 | Qubits dùng: 6 | Time: 15.56s | Acc: 0.7937
#    -> Xong Run 38/50 | Qubits dùng: 6 | Time: 15.40s | Acc: 0.8571
#    -> Xong Run 39/50 | Qubits dùng: 6 | Time: 16.26s | Acc: 0.8095
#    -> Xong Run 40/50 | Qubits dùng: 6 | Time: 15.56s | Acc: 0.7302
#    -> Xong Run 41/50 | Qubits dùng: 6 | Time: 15.79s | Acc: 0.7460
#    -> Xong Run 42/50 | Qubits dùng: 6 | Time: 15.86s | Acc: 0.7937
#    -> Xong Run 43/50 | Qubits dùng: 6 | Time: 15.60s | Acc: 0.7778
#    -> Xong Run 44/50 | Qubits dùng: 6 | Time: 15.40s | Acc: 0.8095
#    -> Xong Run 45/50 | Qubits dùng: 6 | Time: 15.80s | Acc: 0.6984
#    -> Xong Run 46/50 | Qubits dùng: 6 | Time: 15.72s | Acc: 0.7778
#    -> Xong Run 47/50 | Qubits dùng: 6 | Time: 15.84s | Acc: 0.7460
#    -> Xong Run 48/50 | Qubits dùng: 6 | Time: 15.67s | Acc: 0.8254
#    -> Xong Run 49/50 | Qubits dùng: 6 | Time: 15.83s | Acc: 0.7302
#    -> Xong Run 50/50 | Qubits dùng: 6 | Time: 15.32s | Acc: 0.7619
#
# Đang chạy: SONAR | Nhúng: IQP
# Dữ liệu 60 chiều quá lớn cho IQP. Tự động nén PCA xuống 8 chiều!
#    -> Xong Run 1/50 | Qubits dùng: 8 | Time: 29.48s | Acc: 0.5873
#    -> Xong Run 2/50 | Qubits dùng: 8 | Time: 29.51s | Acc: 0.6508
#    -> Xong Run 3/50 | Qubits dùng: 8 | Time: 29.12s | Acc: 0.7460
#    -> Xong Run 4/50 | Qubits dùng: 8 | Time: 29.56s | Acc: 0.6508
#    -> Xong Run 5/50 | Qubits dùng: 8 | Time: 29.30s | Acc: 0.6349
#    -> Xong Run 6/50 | Qubits dùng: 8 | Time: 29.42s | Acc: 0.6667
#    -> Xong Run 7/50 | Qubits dùng: 8 | Time: 29.07s | Acc: 0.7619
#    -> Xong Run 8/50 | Qubits dùng: 8 | Time: 28.84s | Acc: 0.6667
#    -> Xong Run 9/50 | Qubits dùng: 8 | Time: 29.50s | Acc: 0.6667
#    -> Xong Run 10/50 | Qubits dùng: 8 | Time: 29.51s | Acc: 0.7143
#    -> Xong Run 11/50 | Qubits dùng: 8 | Time: 29.42s | Acc: 0.5556
#    -> Xong Run 12/50 | Qubits dùng: 8 | Time: 29.66s | Acc: 0.7302
#    -> Xong Run 13/50 | Qubits dùng: 8 | Time: 29.47s | Acc: 0.6984
#    -> Xong Run 14/50 | Qubits dùng: 8 | Time: 29.42s | Acc: 0.5397
#    -> Xong Run 15/50 | Qubits dùng: 8 | Time: 29.51s | Acc: 0.6825
#    -> Xong Run 16/50 | Qubits dùng: 8 | Time: 29.71s | Acc: 0.6508
#    -> Xong Run 17/50 | Qubits dùng: 8 | Time: 29.16s | Acc: 0.7143
#    -> Xong Run 18/50 | Qubits dùng: 8 | Time: 29.20s | Acc: 0.7143
#    -> Xong Run 19/50 | Qubits dùng: 8 | Time: 29.09s | Acc: 0.7143
#    -> Xong Run 20/50 | Qubits dùng: 8 | Time: 29.04s | Acc: 0.7143
#    -> Xong Run 21/50 | Qubits dùng: 8 | Time: 29.54s | Acc: 0.5714
#    -> Xong Run 22/50 | Qubits dùng: 8 | Time: 29.65s | Acc: 0.5238
#    -> Xong Run 23/50 | Qubits dùng: 8 | Time: 29.62s | Acc: 0.6667
#    -> Xong Run 24/50 | Qubits dùng: 8 | Time: 29.45s | Acc: 0.6667
#    -> Xong Run 25/50 | Qubits dùng: 8 | Time: 29.58s | Acc: 0.7302
#    -> Xong Run 26/50 | Qubits dùng: 8 | Time: 28.43s | Acc: 0.6984
#    -> Xong Run 27/50 | Qubits dùng: 8 | Time: 26.04s | Acc: 0.6984
#    -> Xong Run 28/50 | Qubits dùng: 8 | Time: 25.85s | Acc: 0.7143
#    -> Xong Run 29/50 | Qubits dùng: 8 | Time: 25.88s | Acc: 0.7302
#    -> Xong Run 30/50 | Qubits dùng: 8 | Time: 27.21s | Acc: 0.6984
#    -> Xong Run 31/50 | Qubits dùng: 8 | Time: 25.99s | Acc: 0.6667
#    -> Xong Run 32/50 | Qubits dùng: 8 | Time: 25.84s | Acc: 0.7143
#    -> Xong Run 33/50 | Qubits dùng: 8 | Time: 25.90s | Acc: 0.6032
#    -> Xong Run 34/50 | Qubits dùng: 8 | Time: 25.86s | Acc: 0.6349
#    -> Xong Run 35/50 | Qubits dùng: 8 | Time: 26.35s | Acc: 0.6508
#    -> Xong Run 36/50 | Qubits dùng: 8 | Time: 25.73s | Acc: 0.7302
#    -> Xong Run 37/50 | Qubits dùng: 8 | Time: 25.96s | Acc: 0.6825
#    -> Xong Run 38/50 | Qubits dùng: 8 | Time: 25.64s | Acc: 0.6508
#    -> Xong Run 39/50 | Qubits dùng: 8 | Time: 25.50s | Acc: 0.5714
#    -> Xong Run 40/50 | Qubits dùng: 8 | Time: 26.07s | Acc: 0.5714
#    -> Xong Run 41/50 | Qubits dùng: 8 | Time: 25.57s | Acc: 0.7778
#    -> Xong Run 42/50 | Qubits dùng: 8 | Time: 26.00s | Acc: 0.7143
#    -> Xong Run 43/50 | Qubits dùng: 8 | Time: 25.70s | Acc: 0.7619
#    -> Xong Run 44/50 | Qubits dùng: 8 | Time: 25.73s | Acc: 0.7143
#    -> Xong Run 45/50 | Qubits dùng: 8 | Time: 25.80s | Acc: 0.6508
#    -> Xong Run 46/50 | Qubits dùng: 8 | Time: 25.83s | Acc: 0.6984
#    -> Xong Run 47/50 | Qubits dùng: 8 | Time: 25.84s | Acc: 0.6667
#    -> Xong Run 48/50 | Qubits dùng: 8 | Time: 25.77s | Acc: 0.7302
#    -> Xong Run 49/50 | Qubits dùng: 8 | Time: 25.87s | Acc: 0.6190
#    -> Xong Run 50/50 | Qubits dùng: 8 | Time: 25.73s | Acc: 0.7143
#
# Đang chạy: FASHION | Nhúng: ANGLE
# Dữ liệu 784 chiều quá lớn cho ANGLE. Tự động nén PCA xuống 8 chiều!
#    -> Xong Run 1/50 | Qubits dùng: 8 | Time: 19.85s | Acc: 0.9583
#    -> Xong Run 2/50 | Qubits dùng: 8 | Time: 19.69s | Acc: 0.9583
#    -> Xong Run 3/50 | Qubits dùng: 8 | Time: 19.74s | Acc: 0.9583
#    -> Xong Run 4/50 | Qubits dùng: 8 | Time: 19.72s | Acc: 0.9417
#    -> Xong Run 5/50 | Qubits dùng: 8 | Time: 19.77s | Acc: 0.9583
#    -> Xong Run 6/50 | Qubits dùng: 8 | Time: 19.67s | Acc: 0.9500
#    -> Xong Run 7/50 | Qubits dùng: 8 | Time: 19.69s | Acc: 0.9583
#    -> Xong Run 8/50 | Qubits dùng: 8 | Time: 19.64s | Acc: 0.9750
#    -> Xong Run 9/50 | Qubits dùng: 8 | Time: 19.82s | Acc: 0.9750
#    -> Xong Run 10/50 | Qubits dùng: 8 | Time: 19.67s | Acc: 0.9583
#    -> Xong Run 11/50 | Qubits dùng: 8 | Time: 19.71s | Acc: 0.9417
#    -> Xong Run 12/50 | Qubits dùng: 8 | Time: 20.02s | Acc: 0.9583
#    -> Xong Run 13/50 | Qubits dùng: 8 | Time: 19.72s | Acc: 0.9667
#    -> Xong Run 14/50 | Qubits dùng: 8 | Time: 19.93s | Acc: 0.9500
#    -> Xong Run 15/50 | Qubits dùng: 8 | Time: 19.70s | Acc: 0.9500
#    -> Xong Run 16/50 | Qubits dùng: 8 | Time: 19.78s | Acc: 0.9583
#    -> Xong Run 17/50 | Qubits dùng: 8 | Time: 19.85s | Acc: 0.9750
#    -> Xong Run 18/50 | Qubits dùng: 8 | Time: 19.98s | Acc: 0.9583
#    -> Xong Run 19/50 | Qubits dùng: 8 | Time: 19.77s | Acc: 0.9583
#    -> Xong Run 20/50 | Qubits dùng: 8 | Time: 19.70s | Acc: 0.9750
#    -> Xong Run 21/50 | Qubits dùng: 8 | Time: 19.74s | Acc: 0.9667
#    -> Xong Run 22/50 | Qubits dùng: 8 | Time: 19.84s | Acc: 0.9583
#    -> Xong Run 23/50 | Qubits dùng: 8 | Time: 19.76s | Acc: 0.9750
#    -> Xong Run 24/50 | Qubits dùng: 8 | Time: 19.73s | Acc: 0.9667
#    -> Xong Run 25/50 | Qubits dùng: 8 | Time: 20.01s | Acc: 0.9667
#    -> Xong Run 26/50 | Qubits dùng: 8 | Time: 19.79s | Acc: 0.9833
#    -> Xong Run 27/50 | Qubits dùng: 8 | Time: 19.81s | Acc: 1.0000
#    -> Xong Run 28/50 | Qubits dùng: 8 | Time: 19.96s | Acc: 0.9750
#    -> Xong Run 29/50 | Qubits dùng: 8 | Time: 19.84s | Acc: 0.9583
#    -> Xong Run 30/50 | Qubits dùng: 8 | Time: 19.84s | Acc: 0.9833
#    -> Xong Run 31/50 | Qubits dùng: 8 | Time: 20.60s | Acc: 0.9667
#    -> Xong Run 32/50 | Qubits dùng: 8 | Time: 20.91s | Acc: 0.9333
#    -> Xong Run 33/50 | Qubits dùng: 8 | Time: 20.73s | Acc: 0.9750
#    -> Xong Run 34/50 | Qubits dùng: 8 | Time: 20.55s | Acc: 0.9667
#    -> Xong Run 35/50 | Qubits dùng: 8 | Time: 20.67s | Acc: 0.9667
#    -> Xong Run 36/50 | Qubits dùng: 8 | Time: 20.71s | Acc: 0.9500
#    -> Xong Run 37/50 | Qubits dùng: 8 | Time: 21.00s | Acc: 0.9417
#    -> Xong Run 38/50 | Qubits dùng: 8 | Time: 20.69s | Acc: 0.9583
#    -> Xong Run 39/50 | Qubits dùng: 8 | Time: 20.76s | Acc: 0.9417
#    -> Xong Run 40/50 | Qubits dùng: 8 | Time: 20.60s | Acc: 0.9750
#    -> Xong Run 41/50 | Qubits dùng: 8 | Time: 20.81s | Acc: 0.9333
#    -> Xong Run 42/50 | Qubits dùng: 8 | Time: 20.69s | Acc: 0.9667
#    -> Xong Run 43/50 | Qubits dùng: 8 | Time: 20.85s | Acc: 0.9583
#    -> Xong Run 44/50 | Qubits dùng: 8 | Time: 20.85s | Acc: 0.9583
#    -> Xong Run 45/50 | Qubits dùng: 8 | Time: 20.60s | Acc: 0.9500
#    -> Xong Run 46/50 | Qubits dùng: 8 | Time: 20.97s | Acc: 0.9667
#    -> Xong Run 47/50 | Qubits dùng: 8 | Time: 20.66s | Acc: 0.9083
#    -> Xong Run 48/50 | Qubits dùng: 8 | Time: 20.62s | Acc: 0.9500
#    -> Xong Run 49/50 | Qubits dùng: 8 | Time: 20.74s | Acc: 0.9500
#    -> Xong Run 50/50 | Qubits dùng: 8 | Time: 20.59s | Acc: 0.9417
#
# Đang chạy: FASHION | Nhúng: AMPLITUDE
#    -> Xong Run 1/50 | Qubits dùng: 10 | Time: 26.22s | Acc: 0.9667
#    -> Xong Run 2/50 | Qubits dùng: 10 | Time: 26.29s | Acc: 0.9583
#    -> Xong Run 3/50 | Qubits dùng: 10 | Time: 26.68s | Acc: 0.9250
#    -> Xong Run 4/50 | Qubits dùng: 10 | Time: 26.59s | Acc: 0.9083
#    -> Xong Run 5/50 | Qubits dùng: 10 | Time: 26.72s | Acc: 0.9250
#    -> Xong Run 6/50 | Qubits dùng: 10 | Time: 26.34s | Acc: 0.9750
#    -> Xong Run 7/50 | Qubits dùng: 10 | Time: 26.53s | Acc: 0.9583
#    -> Xong Run 8/50 | Qubits dùng: 10 | Time: 26.54s | Acc: 0.9500
#    -> Xong Run 9/50 | Qubits dùng: 10 | Time: 26.42s | Acc: 0.9000
#    -> Xong Run 10/50 | Qubits dùng: 10 | Time: 26.25s | Acc: 0.9417
#    -> Xong Run 11/50 | Qubits dùng: 10 | Time: 26.53s | Acc: 0.9417
#    -> Xong Run 12/50 | Qubits dùng: 10 | Time: 26.51s | Acc: 0.9583
#    -> Xong Run 13/50 | Qubits dùng: 10 | Time: 26.61s | Acc: 0.9500
#    -> Xong Run 14/50 | Qubits dùng: 10 | Time: 26.53s | Acc: 0.9333
#    -> Xong Run 15/50 | Qubits dùng: 10 | Time: 27.03s | Acc: 0.9500
#    -> Xong Run 16/50 | Qubits dùng: 10 | Time: 26.28s | Acc: 0.9167
#    -> Xong Run 17/50 | Qubits dùng: 10 | Time: 26.48s | Acc: 0.9083
#    -> Xong Run 18/50 | Qubits dùng: 10 | Time: 26.25s | Acc: 0.9167
#    -> Xong Run 19/50 | Qubits dùng: 10 | Time: 26.31s | Acc: 0.9500
#    -> Xong Run 20/50 | Qubits dùng: 10 | Time: 26.60s | Acc: 0.9417
#    -> Xong Run 21/50 | Qubits dùng: 10 | Time: 26.40s | Acc: 0.9500
#    -> Xong Run 22/50 | Qubits dùng: 10 | Time: 26.45s | Acc: 0.9583
#    -> Xong Run 23/50 | Qubits dùng: 10 | Time: 26.36s | Acc: 0.9417
#    -> Xong Run 24/50 | Qubits dùng: 10 | Time: 26.75s | Acc: 0.9500
#    -> Xong Run 25/50 | Qubits dùng: 10 | Time: 26.80s | Acc: 0.9500
#    -> Xong Run 26/50 | Qubits dùng: 10 | Time: 26.35s | Acc: 0.9750
#    -> Xong Run 27/50 | Qubits dùng: 10 | Time: 27.04s | Acc: 0.9750
#    -> Xong Run 28/50 | Qubits dùng: 10 | Time: 26.40s | Acc: 0.9500
#    -> Xong Run 29/50 | Qubits dùng: 10 | Time: 26.49s | Acc: 0.9667
#    -> Xong Run 30/50 | Qubits dùng: 10 | Time: 26.45s | Acc: 0.9500
#    -> Xong Run 31/50 | Qubits dùng: 10 | Time: 26.67s | Acc: 0.9417
#    -> Xong Run 32/50 | Qubits dùng: 10 | Time: 26.44s | Acc: 0.9333
#    -> Xong Run 33/50 | Qubits dùng: 10 | Time: 26.52s | Acc: 0.9417
#    -> Xong Run 34/50 | Qubits dùng: 10 | Time: 26.36s | Acc: 0.9917
#    -> Xong Run 35/50 | Qubits dùng: 10 | Time: 26.42s | Acc: 0.9000
#    -> Xong Run 36/50 | Qubits dùng: 10 | Time: 26.40s | Acc: 0.9333
#    -> Xong Run 37/50 | Qubits dùng: 10 | Time: 26.43s | Acc: 0.9500
#    -> Xong Run 38/50 | Qubits dùng: 10 | Time: 26.51s | Acc: 0.9583
#    -> Xong Run 39/50 | Qubits dùng: 10 | Time: 26.50s | Acc: 0.9333
#    -> Xong Run 40/50 | Qubits dùng: 10 | Time: 26.40s | Acc: 0.9667
#    -> Xong Run 41/50 | Qubits dùng: 10 | Time: 26.44s | Acc: 0.9583
#    -> Xong Run 42/50 | Qubits dùng: 10 | Time: 26.50s | Acc: 0.9333
#    -> Xong Run 43/50 | Qubits dùng: 10 | Time: 26.66s | Acc: 0.9000
#    -> Xong Run 44/50 | Qubits dùng: 10 | Time: 26.47s | Acc: 0.9167
#    -> Xong Run 45/50 | Qubits dùng: 10 | Time: 26.47s | Acc: 0.9333
#    -> Xong Run 46/50 | Qubits dùng: 10 | Time: 26.36s | Acc: 0.9667
#    -> Xong Run 47/50 | Qubits dùng: 10 | Time: 26.60s | Acc: 0.9083
#    -> Xong Run 48/50 | Qubits dùng: 10 | Time: 26.43s | Acc: 0.9083
#    -> Xong Run 49/50 | Qubits dùng: 10 | Time: 26.49s | Acc: 0.9500
#    -> Xong Run 50/50 | Qubits dùng: 10 | Time: 26.45s | Acc: 0.9083
#
# Đang chạy: FASHION | Nhúng: IQP
# Dữ liệu 784 chiều quá lớn cho IQP. Tự động nén PCA xuống 8 chiều!
#    -> Xong Run 1/50 | Qubits dùng: 8 | Time: 28.38s | Acc: 0.9500
#    -> Xong Run 2/50 | Qubits dùng: 8 | Time: 28.29s | Acc: 0.9250
#    -> Xong Run 3/50 | Qubits dùng: 8 | Time: 28.53s | Acc: 0.9417
#    -> Xong Run 4/50 | Qubits dùng: 8 | Time: 27.93s | Acc: 0.9083
#    -> Xong Run 5/50 | Qubits dùng: 8 | Time: 28.29s | Acc: 0.9167
#    -> Xong Run 6/50 | Qubits dùng: 8 | Time: 28.00s | Acc: 0.9083
#    -> Xong Run 7/50 | Qubits dùng: 8 | Time: 28.28s | Acc: 0.9333
#    -> Xong Run 8/50 | Qubits dùng: 8 | Time: 28.01s | Acc: 0.9417
#    -> Xong Run 9/50 | Qubits dùng: 8 | Time: 28.28s | Acc: 0.9333
#    -> Xong Run 10/50 | Qubits dùng: 8 | Time: 27.94s | Acc: 0.9083
#    -> Xong Run 11/50 | Qubits dùng: 8 | Time: 28.12s | Acc: 0.9083
#    -> Xong Run 12/50 | Qubits dùng: 8 | Time: 28.41s | Acc: 0.9250
#    -> Xong Run 13/50 | Qubits dùng: 8 | Time: 28.03s | Acc: 0.8667
#    -> Xong Run 14/50 | Qubits dùng: 8 | Time: 28.18s | Acc: 0.9000
#    -> Xong Run 15/50 | Qubits dùng: 8 | Time: 28.04s | Acc: 0.9250
#    -> Xong Run 16/50 | Qubits dùng: 8 | Time: 28.29s | Acc: 0.9083
#    -> Xong Run 17/50 | Qubits dùng: 8 | Time: 28.06s | Acc: 0.9250
#    -> Xong Run 18/50 | Qubits dùng: 8 | Time: 28.33s | Acc: 0.9083
#    -> Xong Run 19/50 | Qubits dùng: 8 | Time: 28.11s | Acc: 0.9250
#    -> Xong Run 20/50 | Qubits dùng: 8 | Time: 28.47s | Acc: 0.9333
#    -> Xong Run 21/50 | Qubits dùng: 8 | Time: 28.14s | Acc: 0.9083
#    -> Xong Run 22/50 | Qubits dùng: 8 | Time: 28.30s | Acc: 0.9167
#    -> Xong Run 23/50 | Qubits dùng: 8 | Time: 28.02s | Acc: 0.9250
#    -> Xong Run 24/50 | Qubits dùng: 8 | Time: 27.98s | Acc: 0.9000
#    -> Xong Run 25/50 | Qubits dùng: 8 | Time: 28.17s | Acc: 0.9000
#    -> Xong Run 26/50 | Qubits dùng: 8 | Time: 28.32s | Acc: 0.9333
#    -> Xong Run 27/50 | Qubits dùng: 8 | Time: 28.06s | Acc: 0.9667
#    -> Xong Run 28/50 | Qubits dùng: 8 | Time: 28.33s | Acc: 0.9083
#    -> Xong Run 29/50 | Qubits dùng: 8 | Time: 28.25s | Acc: 0.9167
#    -> Xong Run 30/50 | Qubits dùng: 8 | Time: 28.11s | Acc: 0.9750
#    -> Xong Run 31/50 | Qubits dùng: 8 | Time: 28.52s | Acc: 0.9083
#    -> Xong Run 32/50 | Qubits dùng: 8 | Time: 28.15s | Acc: 0.9000
#    -> Xong Run 33/50 | Qubits dùng: 8 | Time: 28.35s | Acc: 0.9083
#    -> Xong Run 34/50 | Qubits dùng: 8 | Time: 28.17s | Acc: 0.9583
#    -> Xong Run 35/50 | Qubits dùng: 8 | Time: 28.10s | Acc: 0.9500
#    -> Xong Run 36/50 | Qubits dùng: 8 | Time: 28.09s | Acc: 0.8750
#    -> Xong Run 37/50 | Qubits dùng: 8 | Time: 28.16s | Acc: 0.9167
#    -> Xong Run 38/50 | Qubits dùng: 8 | Time: 28.23s | Acc: 0.8917
#    -> Xong Run 39/50 | Qubits dùng: 8 | Time: 28.55s | Acc: 0.8750
#    -> Xong Run 40/50 | Qubits dùng: 8 | Time: 27.95s | Acc: 0.8917
#    -> Xong Run 41/50 | Qubits dùng: 8 | Time: 28.21s | Acc: 0.9083
#    -> Xong Run 42/50 | Qubits dùng: 8 | Time: 27.86s | Acc: 0.9000
#    -> Xong Run 43/50 | Qubits dùng: 8 | Time: 27.99s | Acc: 0.9250
#    -> Xong Run 44/50 | Qubits dùng: 8 | Time: 28.40s | Acc: 0.9000
#    -> Xong Run 45/50 | Qubits dùng: 8 | Time: 27.98s | Acc: 0.9250
#    -> Xong Run 46/50 | Qubits dùng: 8 | Time: 28.12s | Acc: 0.9833
#    -> Xong Run 47/50 | Qubits dùng: 8 | Time: 28.36s | Acc: 0.8833
#    -> Xong Run 48/50 | Qubits dùng: 8 | Time: 28.04s | Acc: 0.9333
#    -> Xong Run 49/50 | Qubits dùng: 8 | Time: 28.31s | Acc: 0.9500
#    -> Xong Run 50/50 | Qubits dùng: 8 | Time: 28.18s | Acc: 0.9167
#
# ĐÃ XUẤT THÀNH CÔNG DỮ LIỆU RA FILE: qml_benchmark_results.csv

# %%
# ==============================================================================
# CELL 2: ĐỌC DỮ LIỆU TỪ CSV VÀ VẼ BIỂU ĐỒ 
# ==============================================================================
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns

sns.set_theme(style="whitegrid", context="paper", font_scale=1.2)

def plot_performance_comparison(results_df, dataset_name):
    fig, ax = plt.subplots(figsize=(8, 5))
    df_melted = results_df.melt(id_vars='Embedding', value_vars=['Accuracy', 'F1_Score'], 
                                var_name='Metric', value_name='Score')
    sns.barplot(data=df_melted, x='Embedding', y='Score', hue='Metric', palette='viridis', ax=ax)
    ax.set_title(f'Predictive Performance Comparison ({dataset_name})', fontweight='bold')
    ax.set_ylim(0, 1.1)
    ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    for p in ax.patches:
        ax.annotate(f'{p.get_height():.3f}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='center', xytext=(0, 8), textcoords='offset points', fontsize=10)
    plt.tight_layout()
    plt.savefig(f'fig_perf_{dataset_name}.png', dpi=300)
    plt.show()

def plot_convergence_curves(history_dict, dataset_name):
    fig, ax = plt.subplots(figsize=(8, 5))
    markers, colors = ['o', 's', '^', 'D'], ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
    for i, (emb_name, history) in enumerate(history_dict.items()):
        ax.plot(range(1, len(history) + 1), history, label=emb_name, marker=markers[i%len(markers)], 
                markersize=4, color=colors[i%len(colors)], linewidth=2, alpha=0.8)
    ax.set_title(f'Convergence Comparison - {dataset_name}', fontweight='bold')
    ax.set_xlabel('Epochs')
    ax.set_ylabel('Test Accuracy')
    ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    ax.legend(title="Embedding Methods")
    plt.tight_layout()
    plt.savefig(f'fig_convergence_{dataset_name}.png', dpi=300)
    plt.show()

def plot_tradeoff_analysis(results_df, dataset_name):
    fig, ax = plt.subplots(figsize=(7, 5))
    sns.scatterplot(data=results_df, x='Time_Seconds', y='Accuracy', hue='Embedding', style='Embedding', s=200, palette='Set1', ax=ax)
    ax.set_title(f'Performance vs Cost Trade-off ({dataset_name})', fontweight='bold')
    ax.set_xlabel('Training Time (Seconds)  ← Nhanh hơn | Chậm hơn →')
    ax.set_ylabel('Accuracy')
    ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    
    # Vẽ đường chia cắt chỉ khi có dữ liệu đủ đa dạng
    if len(results_df) > 1:
        ax.axvline(x=results_df['Time_Seconds'].mean(), color='gray', linestyle='--', alpha=0.5)
        ax.axhline(y=results_df['Accuracy'].mean(), color='gray', linestyle='--', alpha=0.5)
        
    plt.tight_layout()
    plt.savefig(f'fig_tradeoff_{dataset_name}.png', dpi=300)
    plt.show()

# ==========================================
# THỰC THI ĐỌC VÀ VẼ
# ==========================================
csv_filename = 'qml_benchmark_results.csv'

try:
    print(f"📂 Đang đọc dữ liệu từ: {csv_filename}")
    df_results = pd.read_csv(csv_filename)
    
    # Giải nén chuỗi JSON trong cột Convergence_History thành kiểu list chuẩn
    df_results['Convergence_History'] = df_results['Convergence_History'].apply(json.loads)
    
    # Tìm tất cả các dataset đã được lưu trong CSV
    datasets_in_csv = df_results['Dataset'].unique()
    
    for ds_name in datasets_in_csv:
        print(f"\n🎨 Đang vẽ đồ thị cho bộ dữ liệu: {ds_name}")
        # Lọc dữ liệu riêng cho từng Dataset
        df_ds = df_results[df_results['Dataset'] == ds_name]
        
        # 1. Vẽ Performance
        plot_performance_comparison(df_ds, ds_name)
        
        # 2. Vẽ Trade-off
        plot_tradeoff_analysis(df_ds, ds_name)
        
        # 3. Chuẩn bị dữ liệu và Vẽ Convergence
        # Biến 2 cột DataFrame thành dict: {'ANGLE': [0.1, 0.2...], 'IQP': [0.1, 0.3...]}
        history_dict = dict(zip(df_ds['Embedding'], df_ds['Convergence_History']))
        plot_convergence_curves(history_dict, ds_name)
        
    print("\n🎉 HOÀN TẤT! Tất cả các biểu đồ đã được vẽ và lưu thành công.")

except FileNotFoundError:
    print(f"❌ Không tìm thấy file '{csv_filename}'. Hãy chắc chắn bạn đã chạy Cell Training trước!")
# Out:
# 📂 Đang đọc dữ liệu từ: qml_benchmark_results.csv
#
# 🎨 Đang vẽ đồ thị cho bộ dữ liệu: SONAR
# 🎨 Đang vẽ đồ thị cho bộ dữ liệu: FASHION
# 🎉 HOÀN TẤT! Tất cả các biểu đồ đã được vẽ và lưu thành công.
